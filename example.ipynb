# %% [markdown]
# # Пример Jupyter Notebook
# Это пример markdown-ячейки с заголовком и текстом.

# %%
print("Привет, мир!")
x = 45
print(f"Результат: {x}")
# Out:
# Привет, мир!
# Результат: 45

# %%
2 + 7
# Out:
# 9

# %%
kv = input("введите данные квартиры")
kl = input("введите данные кладовки")
#kv = 4294.82
#kl = 314.20
itog = round(float(kv) + float(kl),2)
print("Итого: ", itog)
itog2 = int(round(itog - (itog * 0.02),0))
print("Итого для оплаты: ", itog2)
# Out:
# Итого:  35.0
# Итого для оплаты:  34
